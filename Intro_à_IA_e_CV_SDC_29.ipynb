# %% [markdown]
# <a href="https://colab.research.google.com/github/byteLm/Intro_Visao-Computacional_e_IA_com_TF/blob/main/Intro_%C3%A0_IA_e_CV_SDC_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **Introdução à Inteligência Artificial e Visão Computacional com TensorFlow**
#
# ---
#
#
# *Inteligência artificial é uma das áreas mais promissoras na atualidade. Sua base interdisciplinar, bem como sua capacidade multiagente e multiambiente possibilitam aplicações nas mais diversas áreas - trata-se de um novo paradigma para solução de problemas diversos, seja para prever valores de residências, seja para detectar e descriminar objetos em cenas sem definição algorítmica direta.*
#
# *Este minicurso tem como objetivo introduzir os principais conceitos referentes a área de Inteligência Artificial, bem como aprofundar conceitos de Visão Computacional, perpassando pelo desenvolvimento de um classificador de dígitos e roupas, e posteriormente efetuando a detecção destes em cenas, utilizando Redes Neurais Artificiais (ANN) e TensorFlow/Keras API.*
#
# - *Consulte o material completo em:*
#
#  <a href="https://github.com/byteLm/Intro_Visao-Computacional_e_IA_com_TF" target="_blank" rel="noreferrer"><img src="https://raw.githubusercontent.com/danielcranney/readme-generator/main/public/icons/socials/github.svg" width="32" height="32" /></a>
# ````https
# GitHub/Slides: https://github.com/byteLm/Intro_Visao-Computacional_e_IA_com_TF
# ````

# %% [markdown]
# ## **Relação entre X e Y**
# Tradicionalmente, quando desejamos resolver um problema utilizando programação, pensamos em algoritmos que levem a uma solução. De exemplo, podemos descrever funções do tipo:

# %%
def somar(a, b):
    return a + b

# %% [markdown]
# O mesmo vale para **funções e processos mais complexos**, isto é, para relacionar dois valores **X**  ➡   **Y**, definiríamos previamente *a lei de funcionamento*, e por fim obteríamos o resultado:

# %%
def vezesDoisMenosTres(x):
    y = (2 * x) - 3
    return y

# %%
print(vezesDoisMenosTres(5))
# Out:
# 7

# %% [markdown]
# Quando tratamos de [apredizagem de máquina](https://sites.google.com/site/gaudenciothaisia/home/aulas?authuser=0), podemos usar uma abordagem diferente. Enquanto tradicionalmente colocaríamos as regras para saída, iremos "mostrar exemplos" e deixar o algoritmo criá-la. Simples, não?!
#
# Para a função **vezesDoisMenosTres** criada anteriormente, poderíamos definir os seguintes dados como exemplo:

# %%
import numpy as np

Xs = np.array([1, 2, 3, 4], dtype = float) ## Exemplos de entradas
Ys = np.array([-1, 1, 3, 5], dtype = float) ## Respectivas saídas

# %% [markdown]
# Para encontrar a relação entre eles, iremos utilizar apenas **uma camada**, contendo apenas **um neurônio**, que recebe **apenas um valor X como entrada**:

# %%
# Carregando bibliotecas
import tensorflow as tf
from tensorflow import keras

# %%
# Instanciando modelo
model = keras.Sequential(keras.layers.Dense(units=1, input_shape=[1]))

# Compilando
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Realizando treinamento
model.fit(Xs, Ys, epochs = 2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 1s 680ms/step - loss: 5.1067
# Epoch 2/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 3.9315
# Epoch 3/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 3.1137
# Epoch 4/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 2.5440
# Epoch 5/2000
# 1/1 [==============================] - 0s 18ms/step - loss: 2.1464
# Epoch 6/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 1.8682
# Epoch 7/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 1.6729
# Epoch 8/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5352
# Epoch 9/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4373
# Epoch 10/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3672
# Epoch 11/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3164
# Epoch 12/2000
# ...

# %%
# Predição
model.predict([10]) # Você pode testar com outros valores :)
# Out:
# 1/1 [==============================] - 0s 101ms/step
# array([[16.983385]], dtype=float32)

# %% [markdown]
# ### Note que no exemplo acima, ao compilar o modelo, utilizamos a função de perca 'mean_squared_error' (MSE), bem como o otimizador 'Gradiente Descendente Estocástico' (SGD).

# %% [markdown]
# Sobre **funções de custo**, algumas das mais comuns incluem:
#
# * **Erro Quadrático Médio (MSE)**: é uma das funções de custo mais comuns e é usada em problemas de regressão. Ela calcula a média dos erros quadráticos entre as previsões do modelo e os valores alvo.
#
# * **Entropia Cruzada (CE)**: função de custo comumente usada em problemas de classificação. Ela calcula a distância entre a distribuição de probabilidade prevista pelo modelo e a distribuição de probabilidade real.
#
# * **Função Hinge**: usada em problemas de classificação binária e multi-classe e mede o erro no caso de previsões incorretas.
#
# * **Função Logarítmica**: usada em problemas de classificação binária e calcula o logaritmo da diferença entre a previsão do modelo e o valor real.
#
# Cada uma dessas funções de custo tem suas próprias características e limitações e a escolha da função de custo adequada é uma parte importante do projeto de modelos, você pode consultar mais com este [link](https://keras.io/api/losses/).
#
#
# Sobre **[otimizadores](https://keras.io/api/optimizers/)**, eles são usados para atualizar os pesos do nosso modelo durante o treinamento, de forma a minimizar a função de custo. Eles são cruciais para o processo de aprendizagem. São exemplos comuns:
#
# * **Gradiente Descendente (SGD)**: é um dos otimizadores mais básicos e consiste em atualizar os pesos do modelo na direção oposta ao gradiente da função de custo.
#
# * **Gradiente Descendente Estocástico (SGD)**: é uma versão do SGD que atualiza os pesos a cada amostra de treinamento, em vez de fazê-lo após o processamento de todo o conjunto de dados de treinamento.
#
# * **Adam (Adaptive Moment Estimation)**: combina o SGD com a média exponencial dos gradientes anteriores, a fim de melhorar a convergência do treinamento.
#
# * **Adagrad**: ajusta o ritmo de aprendizado individualmente para cada parâmetro, de forma a lidar com features de alta dimensionalidade e de pesos de diferentes magnitude.
#
# * RMSProp: é semelhante ao Adagrad, mas tem uma correção de memória para evitar que o ritmo de aprendizado decaia rapidamente.

# %% [markdown]
# ---
# ## **Visão Computacional**
# ---
#   Quando tratamos de percepção, sem dúvidas um dos sentidos mais importantes é a **visão**. Tarefas que para o ser humano são triviais, como distinção entre dois tipos de objetos ou determinar a localização destes em cena, descrever algoriticamente é uma tarefa bem complicada. Afinal, como descrever limiares do que é ou não é uma cadeira?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ````https
# Fonte Imagem: https://www.theatlantic.com/newsletters/archive/2023/01/diversity-training-paradox-intolerance/672756/
# ````

# %% [markdown]
# Visão Computacional, em seu estado atual, pode ser considerada a junção de **Processamento Digital de Imagens (PDI)** e **Inteligência Artificial**.

# %% [markdown]
# ---
# ### **Classificando dígitos**
# ---

# %% [markdown]
# #### **Contextualização**
# Para classificar imagens, é possível utilizar abordagens clássicas de **PDI** de maneira "pura". Por exemplo, é possível classificar se na figura abaixo está contido **um círculo círculo ou mais**, apenas utilizando **HoG** (histograma de gradientes orientados) - não de maneira simples, mas possível.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

## Carregando imagem 'formas geométricas'
path = "/content/drive/MyDrive/formas-geometricas.png" # Pode utilizar outras imagens! :)
img = cv2.imread(path)
plt.imshow(img) # Exibindo

# Conversão para escala de cinza
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Aplicação filtro de blur
blur = cv2.GaussianBlur(gray, (5, 5), 0)

# Aplicando detecção de bordas com Canny
edges = cv2.Canny(blur, 50, 150, apertureSize=3)

# Informa se há circulos
circles = cv2.HoughCircles(edges, cv2.HOUGH_GRADIENT, 1, 20, param1=50, param2=30, minRadius=0, maxRadius=0)
if circles is not None:
    print("Está contido um círculo!\n")
else:
    print("Não há círculos.\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-3b0954ebb0cf> in <module>
#       6 path = "/content/drive/MyDrive/formas-geometricas.png" # Pode utilizar outras imagens! :)
#       7 img = cv2.imread(path)
# ----> 8 plt.imshow(img) # Exibindo
#       9
#      10 # Conversão para escala de cinza
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2643         filterrad=4.0, imlim=cbook.deprecation._deprecated_parameter,
#    2644         resample=None, url=None, *, data=None, **kwargs):
# -> 2645     __ret = gca().imshow(
#    2646         X, cmap=cmap, norm=norm, aspect=aspect,
#    2647         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ...

# %% [markdown]
# Todavia, essa abordagem não funciona facilmente para o problema de classificação de dígitos. Visualmente, como podemos **diferenciar o 7 e o 2** contidos abaixo? Descrever algoritmicamente, com alta modularidade para casos de testes, é *complicado*.

# %%
# Carregando o dataset mnist do TensorFlow
mnist = tf.keras.datasets.mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

# Plotando dois exemplos
fig, axs = plt.subplots(1,2, figsize=(20, 20))
axs[0].imshow(test_images[0]) # 7
axs[1].imshow(test_images[1]) # 2
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# Para tanto, utilizaremos a mesma abordagem apresentada na relação X/Y, com **um pouco mais de complexidade.**

# %% [markdown]
# #### **Explicando o MNIST**

# %% [markdown]
# **MNIST** é um conjunto de dados de aprendizado de máquina popular, composto por **70.000 imagens** em escala de cinza de **dígitos manuscritos**, contendo **categorias de 0 a 9**. É amplamente utilizado como um *benchmark* para avaliar o desempenho de modelos de visão computacional, bem como é problema clássico do campo - nosso **Hello World**!
#
#
# Ainda que o conjunto de dados **MNIST** seja simples, é possível apresentar conceitos complexos. Além do mais, o conjunto está integrado com o *Keras/Tensorflow*, tendo assim o seu acesso facilitado.

# %% [markdown]
# #### **Carregando e pré-processando MNIST**

# %% [markdown]
# Uma etapa importante, se não a mais importante, antes de efetivamente processarmos informações/dados por uma rede neural, é **pré-processarmos** os dados. Essa tarefa é importante por vários fatores, podemos citar:
#
# - Evitar erros como **'estouro' da representação de ponto flutuante**
# - **Agilizar** o treinamento **diminuindo a amplitude dos pesos**
# - **Evitar viés** do modelo
# - **Remover outliers** ou **ruídos**
#
# Sendo assim, não faremos diferente com o *MNIST*:

# %%
## Inicialmente, iremos carregar o tensorflow
import tensorflow as tf
from tensorflow import keras

## Carregando o dataset
mnist = tf.keras.datasets.mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

#print("\nAntes do processamento:\n\n" + str(test_images[0]))

# %% [markdown]
# ###### Normalização dos dados

# %%
## Iremos normalizar os dados para diminuir a amplitude dos pesos
training_images = training_images/255.0
test_images = test_images/255.0

#print("\nApós o processamento:\n\n" + str(test_images[0]))

# %% [markdown]
# #### **Criando e compilando o modelo**

# %%
# Criando modelo de classificação
modelMNIST = tf.keras.models.Sequential([tf.keras.layers.Flatten(), # Transforma a imagem 28x28 em um array 1D
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu), # Camada com 128 neurônios e ativação ReLu
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)]) # Transforma a saída anterior em probabilidade multiclasse

# Compilando modelo
modelMNIST.compile(optimizer = tf.optimizers.Adam(), # Adam calcula os momentos dos gradientes (isto é, a média e a variação) dos parâmetros do modelo, e utilizá-los para ajustar os pesos de maneira mais precisa.
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# #### **Callbacks!**

# %% [markdown]
# É possível obter informações e utilizá-las de forma precisa durante o treinamento da nossa rede neural, para isto utilizamos *callbacks*. Com callbacks, é possível:
# - Interromper o treinamento quando alguma métrica tenha sido alcançada
# - Salvar *checkpoints* do modelo em métricas específicas
# - Mudar o comportamento do treinamento caso a precisão não esteja melhorando mais
#
# Imagine, por exemplo, almejar 97% de acurácia, conseguir com 20 épocas, mas pré-programar para treinar por 2000 épocas? Podemos evitar facilmente! E é isto que faremos com nossa função abaixo:

# %%
## Callback que interrompe o treinamento quando a acurácia atinge 97%
class stopIfMoreThan97(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.97 and logs.get('loss')<0.0001):
            print("\nAcurácia atingiu 97%!")
            self.model.stop_training = True

callbacks = stopIfMoreThan97()

# %% [markdown]
# Evidentemente, há modelos de *callbacks* contidos *tf.keras*. Abaixo, utilizaremos o tf.keras.callbacks.**EarlyStopping**, ao qual monitora uma determinada métrica (nesse caso, "loss") durante o treinamento de uma rede neural e o interrompe caso essa métrica não melhore por um número específico de épocas

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5) ## Patience se refere a quantidade de épocas que será limiar

# %% [markdown]
# #### **Treinando o modelo**

# %%
modelMNIST.fit(training_images, training_labels, epochs = 5, callbacks = [early_stopping])
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2647 - accuracy: 0.9249
# Epoch 2/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1146 - accuracy: 0.9657
# Epoch 3/5
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0778 - accuracy: 0.9764
# Epoch 4/5
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0590 - accuracy: 0.9822
# Epoch 5/5
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0455 - accuracy: 0.9855

# %%
modelMNIST.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0729 - accuracy: 0.9776
# [0.07293064892292023, 0.9775999784469604]

# %% [markdown]
# #### **Verificando imagens e suas classificações**
# A cada execução de célula, será sorteado qualquer imagem do split de teste

# %%
# Classifica todas as imagens do split de test
classification = modelMNIST.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
import random
indiceAleatorio = random.randint(1, 10000)

plt.imshow(test_images[indiceAleatorio], cmap=plt.cm.binary) # Exibe a imagem
plt.title("Predição = {}".format(np.argmax(classification[indiceAleatorio]))) ## Exibe a predição
plt.show()

# %% [markdown]
# ---
# ### **Rapid Fire Questions**
# ---

# %% [markdown]
# #### **RF|Q1**:
# O conjunto MNIST apresenta a seguinte estrutura:

# %%
# Exibe a primeira imagem do conjunto de treinamento
print(training_images[0].shape)

# %% [markdown]
# Para podermos criar uma entrada mais simplificada para o modelo, podemos inserir uma camada denominada:

# %% [markdown]
# **I**) **Flatten**, responsável por obter principais características da imagem.
#
# **II**) **Conv2D**, responsável por transformar a imagem em um array de uma dimensão.
#
# **III**) **Flatten**, responsável por transformar a imagem em um array de uma dimensão.
#
# **IV**) **Softmax**, responsável por transformar a saída da camada anterior em probabilidades.

# %% [markdown]
# ##### Resposta **RF|Q1**:

# %% [markdown]
# Alternativa correta: **III**

# %% [markdown]
# **A camada Flatten é responsável por transformar a informação de entrada em um array de uma dimensão**, e foi a escolhida para os exemplos anteriores. De fato, também seria possível utilizar uma camada convolucional que obteria as principais informações contidas na entrada, mas sua catergorização está incorreta nas alternativas -  uma camada Convolucional não transforma uma imagem em um array de uma dimensão. Em vez disso, ela aplica filtros a uma imagem, realizando operações matriciais com seus pixels e gerando uma saída chamada mapa de características ou mapa de ativações. Esse mapa de características pode ter uma ou mais dimensões, dependendo da configuração da camada Convolucional.

# %% [markdown]
# #### **RF|Q2**:
# Além de transformarmos a imagem de entrada em um array, aplicamos uma normalização sob os dados. Qual o motivo desta normalização e como ela foi feita?

# %% [markdown]
# I) Cada elemento da entrada foi **dividido por 255**, o que resultou em um valor máximo de 1.0 e um mínimo de 0.0. Dentre outros fatores, esta normalização é importante para evitar que o modelo "estoure" a representação de ponto flutuante.
#
# II) Cada elemento da entrada foi **elevado ao quadrado**, o que resultou em um valor máximo de 255^2 e um mínimo de 0. Esta normalização foi feita para **amplificar as diferenças entre os valores** de cor na imagem.
#
# III) Por haver 10 categorias, a entrada foi normalizada para limitar os valores entre 0 e 10. Deste modo, é possível manter a predição do modelo em valores aproximados a cada categoria, bastando apenas **arredondar o resultado**.

# %% [markdown]
# ##### Resposta **RF|Q3**:

# %% [markdown]
# Alternativa correta: **I**

# %% [markdown]
# Cada elemento divido por 255, efetuando essa normalização dos dados é possível evitar erros como 'estouro' da representação de ponto flutuante, bem como agilizar o treinamento diminuindo a amplitude dos pesos.

# %% [markdown]
# #### **E1|Q3**:
# No modelo acima, ao executar a célula abaixo, recebemos uma lista com valores. O que ela representa?

# %% [markdown]
# I) São 10 valores aleatórios utilizados para depuração.
#
# II) Cada valor representa a respectiva classe.
#
# III) É a probabilidade de cada item considerando as 10 classes.

# %% [markdown]
# Alternativa correta: **III**

# %% [markdown]
# ---
# Além de responder alternativas, consideramos importante um momento para brincar com **alterações**. Reservamos esse espaço para **experimentação**! Ele está completo! Utilize para executar **vários testes**. **Recomendamos alguns**, para cada caso, basta testar! O **bloco está completo com a saída**.
# - Remova as **linhas referentes a normalização**
# - Adicione novas camadas quantidades diferentes (ou iguais) de neurônios
# - Experimente **[outros otimizadores](https://keras.io/api/optimizers/)**
# - Teste **quantidades variadas de épocas**
# - Crie **callbacks** personalizados ou [busque aqui](https://keras.io/api/callbacks/)
#
# Opções são várias! Divirta-se um pouco. =}

# %%
import tensorflow as tf

# Carregando dataset
MNIST =  tf.keras.datasets.mnist
(x_training, y_training),  (x_test, y_test) = mnist.load_data() 

# Normalização
x_training = x_training/255.0 
x_test = x_test/255.0 

# Criando modelo
model = tf.keras.models.Sequential([ 
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(512, activation=tf.nn.relu),
      tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# Compilando modelo
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

# Treinamento
model.fit(training_images, training_labels, epochs=5)
model.evaluate(test_images, test_labels)

# Saída
classifications = model.predict(test_images)
print(classifications[0])
print(test_labels[0])

# %% [markdown]
# ### **Extra module: FMNIST**

# %% [markdown]
# Está contida nesta seção um *playground* referente ao conteúdo apresentado acima, a ideia é que seja possível sintetizar o que foi passado anteriormente, com outro problema semelhante.
#
# ````
# Em caso de dúvidas em momento posterior ao minicurso, sempre é possível entrar em contato - confira a aba referente!
# ````

# %% [markdown]
# *Variante do dataset MNIST*, o **Fashion_MNIST** é um conjunto de dados similar. Trata-se de um dataset com as seguintes características:
# -  **70,000 imagens**
# -  **28x28x1** (Monocromáticas)
# -  **10 Classes variadas**
#
# O conjunto de dados **FMNIST** possui estrutura similiar ao **MNIST** original, sendo portanto um ótimo conjunto para praticarmos; ademais, você poderá acessar o dataset facilmente utilizando o TensorFlow:

# %%
# Carrregando o dataset fmnist
fmnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = fmnist.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# As categorias do **FMNIST** segue a seguinte relação:
# * 0 - **T-shirt/top**
# * 1 - **Trouser**
# * 2 - **Pullover**
# * 3 - **Dress**
# * 4 - **Coat**
# * 5 - **Sandal**
# * 6 - **Shirt**
# * 7 - **Sneaker**
# * 8 - **Bag**
# * 9 - **Ankle boot**
#
# Um exemplo pode ser observado abaixo:

# %%
# Exibindo primeira imagem do conjunto de treinamentoo
plt.imshow(training_images[0])
plt.title("Label: " + str(training_labels[0]))
plt.show()

# %% [markdown]
# ##### Fugindo novamenteda programação convencional e utilizando redes neurais para classificarmos os dados do FMNIST, podemos sintezar estrutura semelhante para também classificar o FMNIST:
#
# - Camada de entrada **Flatten** para transformação do dados de entrada
# - Camada **densa** com **512** neurônios e função de ativação **ReLU**
# - Camada **densa** com **256** neurônios e função de ativação **ReLU**
# - Camada densa com **10** neurônios e função de ativação **Softmax**

# %% [markdown]
# #### [**Playground 1**]:
# Considerando a descrição acima, **complemente a arquitetura** abaixo utilizando Keras/TF:

# %%
import tensorflow as tf
from tensorflow import keras


# Criando o modelo de classificação
model = keras.Sequential([
    tf.keras.layers."A"(), # utilize tf.keras.layers.CAMADA
    tf.keras.layers."B"("D", "F"), # lembre-se de também passar parametros, se necessário
    tf.keras.layers."C"("E", "G")
])

# %% [markdown]
# ##### Resposta **PL1**:

# %%
# Criando modelo de classificação
model = tf.keras.models.Sequential([tf.keras.layers.Flatten(), # Camada Flatten que transforma a imagem 28x28 em um array 1D
                                    tf.keras.layers.Dense(512, activation=tf.nn.relu), # Camada densa, com 512 neurônios e função de ativação ReLu
                                    tf.keras.layers.Dense(256, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax),]) # Camada de classificação com Softmax

# %% [markdown]
# #### [**Playground 2**]:
# Para processarmos o **FMNIST**, é necessário ainda **compilarmos** o modelo criado.

# %%
# Compilando modelo
model.compile(optimizer = tf.optimizers.INSERT(), # Insira o otimizador
              loss = "INSERT", # Insira a função de custo
              metrics=['INSERT']) # Insira uma métrica desejada

# %% [markdown]
# ##### Resposta **PL2**:

# %%
model.compile(optimizer = tf.optimizers.Adam(), # Otimizador
              loss = "sparse_categorical_crossentropy", # Função de custo
              metrics=['accuracy']) # Métrica desejada

# %% [markdown]
# #### [**Playground 3**]:
# Por fim, é necessário **realizar o treinamento**.

# %%
someCallback = tf.keras.callbacks.CALLBACK() ## lembre-se: pode ser uma função personalizada!
model.fit("some", "thing", "here")
model.evaluate("and", "here", "too")

# %% [markdown]
# ##### Resposta **PL3**:

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
model.fit(training_images, training_labels, epochs = 10, callbacks=[ealy_stopping])
model.evaluate(test_images, test_labels)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 2.2472 - accuracy: 0.7702
# Epoch 2/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.5400 - accuracy: 0.8186
# Epoch 3/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.4601 - accuracy: 0.8374
# Epoch 4/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.4116 - accuracy: 0.8526
# Epoch 5/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3909 - accuracy: 0.8592
# Epoch 6/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3838 - accuracy: 0.8626
# Epoch 7/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3761 - accuracy: 0.8665
# Epoch 8/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3605 - accuracy: 0.8719
# Epoch 9/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3544 - accuracy: 0.8727
# Epoch 10/10
# ...

# %% [markdown]
# #### Verificação Playground

# %%
# Classifica todas as imagens do split de test
classification = modelMNIST.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
import random
indiceAleatorio = random.randint(1, 10000)


class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']


plt.imshow(test_images[indiceAleatorio], cmap=plt.cm.binary) # Exibe a imagem
plt.title("Predição = {}".format(class_names[np.argmax(classification[indiceAleatorio])])) ## Exibe a predição
plt.show()

# %% [markdown]
# ---
# ## **LINKS ÚTEIS**
# ---

# %% [markdown]
# *Aqui você pode conferir materiais de referência, materiais que consideramos de boa consulta, bem como informações sobre nós.*

# %% [markdown]
# ---
# **REFERENCIAL**
# - [Documentação Tensorflow](https://www.tensorflow.org/tutorials?hl=pt-br)
# - [Documentação Keras](https://keras.io/api/)
# - [Adam: A Method for Stochastic Optimization](https://arxiv.org/abs/1412.6980)
# - [Cross-Entropy Loss Function](https://towardsdatascience.com/cross-entropy-loss-function-f38c4ec8643e)
# - [Introdução à Inteligência Artificial](https://sites.google.com/site/gaudenciothaisia/home/aulas?authuser=0)
# - [Deeplearning.AI](https://github.com/https-deeplearning-ai/tensorflow-1-public)

# %% [markdown]
# ---
#
# > ![luccas.freitas.png](data:image/png;base64,...)
#
# ### **LUCCAS M. T. FREITAS**
# <p align="left"> <a href="https://www.github.com/bytelm" target="_blank" rel="noreferrer"><img src="https://raw.githubusercontent.com/danielcranney/readme-generator/main/public/icons/socials/github.svg" width="32" height="32" /></a> <a href="https://www.linkedin.com/in/luccas-freitas" target="_blank" rel="noreferrer"><img src="https://raw.githubusercontent.com/danielcranney/readme-generator/main/public/icons/socials/linkedin.svg" width="32" height="32" /></a></p>
#
# - *luccas.matheus@academico.ufpb.br*
#
# ---
# ````
# Graduando em Engenharia de Computação pela UFPB, é atualmente estagiário de P&D na Vsoft; também realiza
# pesquisa científica no âmbito de Visão Computacional aplicada a Sensoriamento Remoto.
# ````
# ---

# %% [markdown]
# > ![lucas.png](data:image/png;base64,...)
#
# ### **LUCAS GOMES DANTAS**
# <p align="left"> <a href="http://github.com/tazc0de" target="_blank" rel="noreferrer"><img src="https://raw.githubusercontent.com/danielcranney/readme-generator/main/public/icons/socials/github.svg" width="32" height="32" /></a> <a href="https://www.linkedin.com/in/lucas-dantas-92517b163/" target="_blank" rel="noreferrer"><img src="https://raw.githubusercontent.com/danielcranney/readme-generator/main/public/icons/socials/linkedin.svg" width="32" height="32" /></a></p>
#
# - *lgd@academico.ufpb.br*
#
# ---
# ````
# Graduando em Ciência da Computação pela UFPB, é atualmente estagiário em Visão Computacional na IARIS Tech; também realiza pesquisa
# científica em visão computacional nos segmentos de sensoriamento remoto e detecção de doenças em folhas.
# ````
# ---
